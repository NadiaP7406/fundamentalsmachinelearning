# %% [markdown]
# # Gender prediction by voice #

# %%
import seaborn as sns
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split #We need this to split the data

# %%
df = pd.read_csv("voice.csv")
df.head(10)
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# 5  0.132786  0.079557  0.119090  0.067958  0.209592  0.141634   1.932562
# 6  0.150762  0.074463  0.160106  0.092899  0.205718  0.112819   1.530643
# 7  0.160514  0.076767  0.144337  0.110532  0.231962  0.121430   1.397156
# 8  0.142239  0.078018  0.138587  0.088206  0.208587  0.120381   1.099746
# 9  0.134329  0.080350  0.121451  0.075580  0.201957  0.126377   1.190368
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# ...

# %% [markdown]
# ## Exploratory data analysis ##

# %%
# dummies = pd.get_dummies(df['label'])
# df = pd.concat([df, dummies], axis=1) #the axis=1 means: add it to the columns (axis=0 is rows)
df.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %% [markdown]
# From the correlation matrix I can see which variables strongly relate to the male/female label.
# I select those as my features and create a new df with only those in it to save my computer.

# %%
df = df[["meanfun", "Q25", "meanfreq", "IQR", "sp.ent", "sd", "label"]]
df.head(10)
# Out:
#     meanfun       Q25  meanfreq       IQR    sp.ent        sd label
# 0  0.084279  0.015071  0.059781  0.075122  0.893369  0.064241  male
# 1  0.107937  0.019414  0.066009  0.073252  0.892193  0.067310  male
# 2  0.098706  0.008701  0.077316  0.123207  0.846389  0.083829  male
# 3  0.088965  0.096582  0.151228  0.111374  0.963322  0.072111  male
# 4  0.106398  0.078720  0.135120  0.127325  0.971955  0.079146  male
# 5  0.110132  0.067958  0.132786  0.141634  0.963181  0.079557  male
# 6  0.105945  0.092899  0.150762  0.112819  0.967573  0.074463  male
# 7  0.093052  0.110532  0.160514  0.121430  0.959255  0.076767  male
# 8  0.096729  0.088206  0.142239  0.120381  0.970723  0.078018  male
# 9  0.105881  0.075580  0.134329  0.126377  0.975246  0.080350  male

# %%
sns.pairplot(df)
plt.show() #using Matplotlib to show the plot

# %% [markdown]
# ## Building a model

# %%
X = df[["meanfun", "Q25", "meanfreq", "IQR", "sp.ent", "sd"]] #create the X matrix

y = df['label'] #create the y-variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) #split the data, store it into different variables

X_train.head() #show the head of the training set
# Out:
#        meanfun       Q25  meanfreq       IQR    sp.ent        sd
# 1866  0.174179  0.043235  0.141083  0.174542  0.941751  0.088698
# 767   0.100181  0.106603  0.167021  0.100853  0.908148  0.057011
# 2862  0.179095  0.223822  0.234486  0.028535  0.813883  0.034413
# 1064  0.138659  0.138016  0.197073  0.105827  0.911062  0.057609
# 270   0.108932  0.094235  0.142018  0.108663  0.940602  0.071383

# %% [markdown]
# I decided to use KNeighborsClassifier.

# %%
from sklearn.neighbors import KNeighborsClassifier #the object class we need

knn = KNeighborsClassifier(n_neighbors=3) #create a KNN-classifier with 3 neighbors
knn = knn.fit(X_train, y_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ## Evaluating the model ##
#
# Evaluate your model here, on the data that you were given (training data). This code can be ran multiple times with different models, if you want, to determine the best model (but beware of overfitting!). Use RMSE as your metric.

# %%
knn.score(X_test, y_test) #calculate the fit on the *test* data
# Out:
# 0.9758149316508938

# %% [markdown]
# Accuracy on testing set is 97% which is good :)

# %%
from sklearn.metrics import confusion_matrix
y_test_pred = knn.predict(X_test) #the predicted values
cm = confusion_matrix(y_test, y_test_pred) #creates a "confusion matrix"
cm
# Out:
# array([[449,   8],
#        [ 15, 479]])

# %%
knn.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
conf_matrix = pd.DataFrame(cm, index=['Female (actual)', 'Male (actual)'], columns = ['Female (predicted)', 'Male (predicted)']) #make a dataframe, put labels on rows (index) and columns 
conf_matrix
# Out:
#                  Female (predicted)  Male (predicted)
# Female (actual)                 449                 8
# Male (actual)                    15               479
